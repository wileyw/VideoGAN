# %% [markdown]
# <a href="https://colab.research.google.com/github/wileyw/VideoGAN/blob/master/Visualize/VisualizeVideoGANExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install torchviz
import torch
from torch import nn
from torchviz import make_dot
from torch.autograd import Variable

model = nn.Sequential()
model.add_module('W0', nn.Linear(8, 16))
model.add_module('tanh', nn.Tanh())
model.add_module('W1', nn.Linear(16, 1))

# Torch Tensors are the actual data
# Torch Variables are wrappers around Tensors and link a chain of operations together so that gradients can flow back
x = Variable(torch.randn(1, 8))
y = model(x)

make_dot(y.mean(), params=dict(model.named_parameters()))
# Out:
# ...
#      |████████████████████████████████| 51kB 3.9MB/s
# ...
#   Created wheel for torchviz: filename=torchviz-0.0.1-cp36-none-any.whl size=3520 sha256=1a26959043e5dd36b0e212bc0dec05de6dd41bbc9c70920360e5b9abde3f6d9f
#   Stored in directory: /root/.cache/pip/wheels/2a/c2/c5/b8b4d0f7992c735f6db5bfa3c5f354cf36502037ca2b585667
# Successfully built torchviz
# ...
